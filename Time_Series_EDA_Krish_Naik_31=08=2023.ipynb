# %% [markdown]
# ## Time Series EDA

# %% [markdown]
# https://github.com/krishnaik06/Live-Time-Series/blob/main/Time%20Series%20EDA.ipynb

# %%
## Install Pandas Data Reader
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#dir(pdr)

# %%
#help(get_data_yahoo)

# %%
#import pandas_datareader.get_data_yahoo

# %%
#help(pdr)

# %%
# def get_data_yahoo(*args, **kwargs):
#   return YahooDailyReader(*args, **kwargs).read()

# %%
# pdr.get_data_yahoo("TSLA")

# %% [markdown]
# https://stackoverflow.com/questions/69717359/error-using-pandas-datareader-no-data-fetched-using-yahoodailyreader

# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()

df = pdr.get_data_yahoo("TSLA", start="2017-02-27", end="2022-02-25")
print(df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...                ...         ...         ...         ...         ...
# 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
# 2022-02-24  233.463333  267.493347  233.333328  266.923340  266.923340
#
#                Volume
# Date
# ...

# %%
1259/365
# Out:
# 3.4493150684931506

# %%
df_tesla=pdr.get_data_yahoo('TSLA')
df_tesla=df
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.shape
# Out:
# (1259, 6)

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
# 2022-02-24  233.463333  267.493347  233.333328  266.923340  266.923340
#
#                Volume
# Date
# 2022-02-17   55178400
# 2022-02-18   68501700
# 2022-02-22   83288100
# 2022-02-23   95256900
# 2022-02-24  135322200

# %%
df_tesla.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Low'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Close'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Adj Close'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Volume'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #2017-02-27 se lekar 2022-02-23

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4)).grid()

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4)).grid()

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4), c ='green').grid()

# %%
## xlimit and y limit and coloring
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4),ls='--',c='green').grid()#ls =line style

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10',
#                ...
#                '2022-02-10', '2022-02-11', '2022-02-14', '2022-02-15',
#                '2022-02-16', '2022-02-17', '2022-02-18', '2022-02-22',
#                '2022-02-23', '2022-02-24'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
df_tesla.shape
# Out:
# (1259, 6)

# %%
df_tesla.loc['2020-01-01':'2021-09-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2021-08-26  236.103333  238.466660  232.539993  233.720001  233.720001
# 2021-08-27  235.000000  238.333328  234.033340  237.306671  237.306671
# 2021-08-30  238.240005  243.666672  237.576660  243.636673  243.636673
# 2021-08-31  244.333328  246.796661  242.146667  245.240005  245.240005
# 2021-09-01  244.693329  247.330002  243.756668  244.696671  244.696671
#
#                Volume
# Date
# 2020-01-02  142981500
# 2020-01-03  266677500
# 2020-01-06  151995000
# ...

# %%
df_tesla.loc['2020-01-01':'2021-09-01'].index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
df_tesla.loc['2020-01-01':'2021-09-01']['Open']
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index

share_open=df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
share_open # you are going to get open dataset
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
axis.plot(index,share_open)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
axis.plot(index,share_open)

# %%
figure,axis=plt.subplots()
plt.tight_layout()

## Preventing overlapping
figure.autofmt_xdate()#auto format x date
axis.plot(index,share_open)

# %%
## Datetime Index

# %%
df_tesla=df_tesla.reset_index()
#if u re run it anothre column index will be added to it.

# %%
df_tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 1    2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2    2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 3    2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 4    2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...         ...         ...         ...         ...         ...         ...
# 1254 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 1255 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 1256 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 1257 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
# 1258 2022-02-24  233.463333  267.493347  233.333328  266.923340  266.923340
#
#          Volume
# 0     171912000
# 1      91171500
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
#pd.to_datetime(df_tesla['Date'])

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...                ...         ...         ...         ...         ...
# 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
# 2022-02-24  233.463333  267.493347  233.333328  266.923340  266.923340
#
#                Volume
# Date
# 2017-02-27  171912000
# 2017-02-28   91171500
# 2017-03-01   72142500
# ...

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10',
#                ...
#                '2022-02-10', '2022-02-11', '2022-02-14', '2022-02-15',
#                '2022-02-16', '2022-02-17', '2022-02-18', '2022-02-22',
#                '2022-02-23', '2022-02-24'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()#abhee ka samay batayega
# Out:
# datetime.datetime(2023, 9, 1, 7, 36, 46, 263047)

# %%
def add_num(num1, num2):
  return num1+num2

# %%
start_time =datetime.now()
num1 = 20
num2 = 30
add_num(num1, num2)
end_time = datetime.now()
print(end_time-start_time)
# Out:
# 0:00:00.000218

# %%
start_time =datetime.now()
num1 = 20
num2 = 30
for i in [1,2,3,4,5]:
  add_num(num1, num2)
end_time = datetime.now()
print(end_time-start_time)
# Out:
# 0:00:00.000235

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()#6TH DAY
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# ## Time Resampling vvi

# %% [markdown]
# https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000

# %%
df_tesla.resample(rule='A').min()#har saal ka data print karega...write the min low
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   16.279333   16.433332   16.134001   16.246000   16.246000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# 2022-12-31  233.463333  267.493347  233.333328  254.679993  254.679993
#
#               Volume
# Date
# 2017-12-31  43791000
# 2018-12-31  46210500
# 2019-12-31  36984000
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  50729100

# %%
df_tesla.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-31  396.516663  402.666656  378.679993  399.926666  399.926666
#
#                Volume
# Date
# 2017-12-31  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-31  151565700

# %%
type(df_tesla.resample(rule='A').max())
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.resample(rule='A').max()['Open']
# Out:
# Date
# 2017-12-31     25.779333
# 2018-12-31     25.000000
# 2019-12-31     29.000000
# 2020-12-31    233.330002
# 2021-12-31    411.470001
# 2022-12-31    396.516663
# Freq: A-DEC, Name: Open, dtype: float64

# %% [markdown]
# #Rule A means Year and Frequency

# %%
##year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_tesla.resample(rule='QS').max()['High']
# Out:
# Date
# 2017-01-01     18.799999
# 2017-04-01     25.799334
# 2017-07-01     25.974001
# 2017-10-01     24.200001
# 2018-01-01     24.033333
# 2018-04-01     24.915333
# 2018-07-01     25.830667
# 2018-10-01     25.299334
# 2019-01-01     23.466667
# 2019-04-01     19.744667
# 2019-07-01     17.738001
# 2019-10-01     29.020666
# 2020-01-01     64.599335
# 2020-04-01     72.512665
# 2020-07-01    167.496674
# 2020-10-01    239.573334
# 2021-01-01    300.133331
# 2021-04-01    260.263336
# 2021-07-01    266.333344
# 2021-10-01    414.496674
# 2022-01-01    402.666656
# Freq: QS-JAN, Name: High, dtype: float64

# %%
##quaterly start frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
##Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='BA').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-30  396.516663  402.666656  378.679993  399.926666  399.926666
#
#                Volume
# Date
# 2017-12-29  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-30  151565700

# %%
df_tesla.resample(rule='BA').max().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-02   18.582001   18.799999   18.480667   18.553333   18.553333
# 2017-04-03   25.779333   25.799334   25.290001   25.563334   25.563334
# 2017-07-03   25.350000   25.974001   25.178667   25.666668   25.666668
# 2017-10-02   23.798668   24.200001   23.608667   23.976667   23.976667
# 2018-01-01   24.000000   24.033333   23.490667   23.827999   23.827999
# 2018-04-02   24.344000   24.915333   23.633333   24.722000   24.722000
# 2018-07-02   24.606001   25.830667   24.474667   25.304667   25.304667
# 2018-10-01   25.000000   25.299334   24.450001   25.119333   25.119333
# 2019-01-01   23.080667   23.466667   22.943333   23.153999   23.153999
# 2019-04-01   19.219999   19.744667   19.144667   19.454000   19.454000
# 2019-07-01   17.278000   17.738001   17.210667   17.658667   17.658667
# 2019-10-01   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
df_tesla.resample(rule='BQS').max().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #=================================

# %%
##plotting
df_tesla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
##plotting
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max()
# Out:
# Date
# 2017-02-28     16.544666
# 2017-03-31     18.582001
# 2017-04-30     20.892000
# 2017-05-31     22.512667
# 2017-06-30     25.779333
#                  ...
# 2021-10-31    360.619995
# 2021-11-30    411.470001
# 2021-12-31    386.899994
# 2022-01-31    396.516663
# 2022-02-28    311.736664
# Freq: M, Name: Open, Length: 61, dtype: float64

# %%
df_tesla['Open'].resample(rule='M').max().shape
# Out:
# (61,)

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #====================================================

# %% [markdown]
# #rolling and exPANDING

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000
#
#             Open:30 days rolling
# Date
# 2017-02-27                   NaN
# 2017-02-28                   NaN
# 2017-03-01                   NaN
# 2017-03-02                   NaN
# 2017-03-03                   NaN

# %%
df_tesla['High'].rolling(10) #rolling is inbuilt function axis =0 is for rows
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
df_tesla['High'].rolling(10).mean()
# Out:
# Date
# 2017-02-27           NaN
# 2017-02-28           NaN
# 2017-03-01           NaN
# 2017-03-02           NaN
# 2017-03-03           NaN
#                  ...
# 2022-02-17    309.447000
# 2022-02-18    307.792667
# 2022-02-22    304.757999
# 2022-02-23    301.724997
# 2022-02-24    296.931998
# Name: High, Length: 1259, dtype: float64

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000
#
#             Open:30 days rolling
# Date
# 2017-02-27                   NaN
# 2017-02-28                   NaN
# 2017-03-01                   NaN
# 2017-03-02                   NaN
# 2017-03-03                   NaN

# %%
df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2017-02-27          NaN
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10    16.734733
# 2017-03-13    16.724667
# 2017-03-14    16.772133
# 2017-03-15    16.813133
# 2017-03-16    16.896267
# 2017-03-17    16.985800
# 2017-03-20    17.071467
# 2017-03-21    17.144200
# 2017-03-22    17.177534
# 2017-03-23    17.237600
# 2017-03-24    17.353534
# Name: High, dtype: float64

# %%
df_tesla['High'].rolling(11).mean().head(20)
# Out:
# Date
# 2017-02-27          NaN
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10          NaN
# 2017-03-13    16.709454
# 2017-03-14    16.768606
# 2017-03-15    16.829212
# 2017-03-16    16.895273
# 2017-03-17    16.968303
# 2017-03-20    17.044970
# 2017-03-21    17.124364
# 2017-03-22    17.131515
# 2017-03-23    17.177576
# 2017-03-24    17.269879
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000
#
#             Open:30 days rolling
# Date
# 2017-02-27                   NaN
# 2017-02-28                   NaN
# 2017-03-01                   NaN
# 2017-03-02                   NaN
# 2017-03-03                   NaN

# %%
df_tesla['High'].rolling(11).max().head(20)

# rolling means == provides rolling window calculation
# Out:
# Date
# 2017-02-27          NaN
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10          NaN
# 2017-03-13    16.990000
# 2017-03-14    17.208000
# 2017-03-15    17.400000
# 2017-03-16    17.716667
# 2017-03-17    17.716667
# 2017-03-20    17.716667
# 2017-03-21    17.716667
# 2017-03-22    17.716667
# 2017-03-23    17.716667
# 2017-03-24    17.716667
# Name: High, dtype: float64

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-rolling/

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-02-27  16.544666  16.557333  16.134001  16.415333  16.415333  171912000
# 2017-02-28  16.279333  16.733334  16.260000  16.666000  16.666000   91171500
# 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999   72142500
# 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668   50277000
# 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334   43791000
# 2017-03-06  16.527332  16.780001  16.500668  16.747334  16.747334   50332500
# 2017-03-07  16.794666  16.926001  16.554667  16.572666  16.572666   51892500
# 2017-03-08  16.466667  16.671333  16.354668  16.458000  16.458000   55878000
# 2017-03-09  16.508667  16.577333  16.200001  16.326668  16.326668   58189500
# 2017-03-10  16.414000  16.433332  16.200001  16.246000  16.246000   45994500
# 2017-03-13  16.321333  16.456667  16.185333  16.411333  16.411333   45339000
# ...

# %%
df_tesla[['Open','Open:30 days rolling']]
# Out:
#                   Open  Open:30 days rolling
# Date
# 2017-02-27   16.544666                   NaN
# 2017-02-28   16.279333                   NaN
# 2017-03-01   16.945333                   NaN
# 2017-03-02   16.647333                   NaN
# 2017-03-03   16.716000                   NaN
# ...                ...                   ...
# 2022-02-17  304.420013            319.067332
# 2022-02-18  295.333344            316.945110
# 2022-02-22  278.043335            314.209111
# 2022-02-23  276.809998            312.324999
# 2022-02-24  233.463333            308.399666
#
# [1259 rows x 2 columns]

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ##Assignment
# ##news
# 1. Read the Microsoft Data using Pandas Data reader
# 2. Get the maximum price of the share from 2017 to 2022
# 3. Which is the date of the highest price of the stock?
# 4. Which is the date of the lowest price of the stock?
