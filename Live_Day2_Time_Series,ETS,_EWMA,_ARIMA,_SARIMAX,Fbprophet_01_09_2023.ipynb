# %%
# !pip install pandas_datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()

df = pdr.get_data_yahoo("TSLA", start="2017-02-27", end="2022-02-25")
print(df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...                ...         ...         ...         ...         ...
# 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
# 2022-02-24  233.463333  267.493347  233.333328  266.923340  266.923340
#
#                Volume
# Date
# ...

# %%
df_tesla =pdr.get_data_yahoo('TSLA')
df_tesla
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-08-28  242.580002  244.380005  235.350006  238.820007  238.820007
# 2023-08-29  238.580002  257.480011  237.770004  257.179993  257.179993
# 2023-08-30  254.199997  260.510010  250.589996  256.899994  256.899994
# 2023-08-31  255.979996  261.179993  255.050003  258.079987  258.079987
# 2023-09-01  257.260010  259.079407  242.009995  243.924698  243.924698
#
#                Volume
# Date
# ...

# %%
df_tesla =pdr.get_data_yahoo('TSLA',start="2017-02-27", end="2022-02-26")
df_tesla
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-27   16.544666   16.557333   16.134001   16.415333   16.415333
# 2017-02-28   16.279333   16.733334   16.260000   16.666000   16.666000
# 2017-03-01   16.945333   16.990000   16.607332   16.667999   16.667999
# 2017-03-02   16.647333   16.885332   16.551332   16.698668   16.698668
# 2017-03-03   16.716000   16.793333   16.600000   16.771334   16.771334
# ...                ...         ...         ...         ...         ...
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
# 2022-02-24  233.463333  267.493347  233.333328  266.923340  266.923340
# 2022-02-25  269.743347  273.166656  260.799988  269.956665  269.956665
#
#                Volume
# Date
# ...

# %% [markdown]
# #Simple Moving Average

# %%
df_tesla['Open']
# Out:
# Date
# 2017-02-27     16.544666
# 2017-02-28     16.279333
# 2017-03-01     16.945333
# 2017-03-02     16.647333
# 2017-03-03     16.716000
#                  ...
# 2022-02-18    295.333344
# 2022-02-22    278.043335
# 2022-02-23    276.809998
# 2022-02-24    233.463333
# 2022-02-25    269.743347
# Name: Open, Length: 1260, dtype: float64

# %%
df_tesla['Open'].plot(figsize =(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].rolling(window =10,min_periods =1)
# Out:
# Rolling [window=10,min_periods=1,center=False,axis=0,method=single]

# %%
df_tesla['Open:10 days rolling'] = df_tesla['Open'].rolling(window =10,min_periods =1).mean()

# %%
df_tesla[['Open','Open:10 days rolling']]
# Out:
#                   Open  Open:10 days rolling
# Date
# 2017-02-27   16.544666             16.544666
# 2017-02-28   16.279333             16.412000
# 2017-03-01   16.945333             16.589778
# 2017-03-02   16.647333             16.604167
# 2017-03-03   16.716000             16.626533
# ...                ...                   ...
# 2022-02-18  295.333344            301.906665
# 2022-02-22  278.043335            298.917999
# 2022-02-23  276.809998            296.414667
# 2022-02-24  233.463333            288.594334
# 2022-02-25  269.743347            285.289668
#
# [1260 rows x 2 columns]

# %%
df_tesla[['Open','Open:10 days rolling']].plot(figsize =(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01' ,'2021-01-01'],figsize =(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #For 30 Rolling

# %%
df_tesla['Open:30 days rolling'] = df_tesla['Open'].rolling(window =30,min_periods =1).mean()
df_tesla['Open:50 days rolling'] = df_tesla['Open'].rolling(window =50,min_periods =1).mean()

# %%
df_tesla['Open:30 days rolling']
# Out:
# Date
# 2017-02-27     16.544666
# 2017-02-28     16.412000
# 2017-03-01     16.589778
# 2017-03-02     16.604167
# 2017-03-03     16.626533
#                  ...
# 2022-02-18    316.945110
# 2022-02-22    314.209111
# 2022-02-23    312.324999
# 2022-02-24    308.399666
# 2022-02-25    305.403888
# Name: Open:30 days rolling, Length: 1260, dtype: float64

# %%
df_tesla['Open:50 days rolling']
# Out:
# Date
# 2017-02-27     16.544666
# 2017-02-28     16.412000
# 2017-03-01     16.589778
# 2017-03-02     16.604167
# 2017-03-03     16.626533
#                  ...
# 2022-02-18    327.870466
# 2022-02-22    326.360399
# 2022-02-23    325.171599
# 2022-02-24    323.166933
# 2022-02-25    322.261800
# Name: Open:50 days rolling, Length: 1260, dtype: float64

# %%
df_tesla[['Open','Open:10 days rolling','Open:30 days rolling','Open:50 days rolling']].plot(xlim=['2020-01-01' ,'2021-01-01'],figsize =(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].expanding().mean()
# Out:
# Date
# 2017-02-27    16.544666
# 2017-02-28    16.412000
# 2017-03-01    16.589778
# 2017-03-02    16.604167
# 2017-03-03    16.626533
#                 ...
# 2022-02-18    91.921126
# 2022-02-22    92.069194
# 2022-02-23    92.216047
# 2022-02-24    92.328237
# 2022-02-25    92.469043
# Name: Open, Length: 1260, dtype: float64

# %%
## Expanding
df_tesla['Open'].expanding().mean().plot(figsize =(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#EWMA= Exponential Weighted Moving Average

# %%
##EMA tesla shares
# Let's smoothing factor - 0.1
df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha =0.1,adjust =False).mean()
#aplha is hyper  parameter and it is called smoothing factor

# %%
df_tesla['EMA_0.1'] #
# Out:
# Date
# 2017-02-27     16.544666
# 2017-02-28     16.518133
# 2017-03-01     16.560853
# 2017-03-02     16.569501
# 2017-03-03     16.584151
#                  ...
# 2022-02-18    306.989372
# 2022-02-22    304.094768
# 2022-02-23    301.366291
# 2022-02-24    294.575995
# 2022-02-25    292.092730
# Name: EMA_0.1, Length: 1260, dtype: float64

# %%
df_tesla[['Open','EMA_0.1']]
# Out:
#                   Open     EMA_0.1
# Date
# 2017-02-27   16.544666   16.544666
# 2017-02-28   16.279333   16.518133
# 2017-03-01   16.945333   16.560853
# 2017-03-02   16.647333   16.569501
# 2017-03-03   16.716000   16.584151
# ...                ...         ...
# 2022-02-18  295.333344  306.989372
# 2022-02-22  278.043335  304.094768
# 2022-02-23  276.809998  301.366291
# 2022-02-24  233.463333  294.575995
# 2022-02-25  269.743347  292.092730
#
# [1260 rows x 2 columns]

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim=['2020-01-01' ,'2021-01-01'],figsize =(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['EMA_0.3'] = df_tesla['Open'].ewm(alpha =0.3,adjust =False).mean()

# %%
df_tesla['EMA_0.3']
# Out:
# Date
# 2017-02-27     16.544666
# 2017-02-28     16.465066
# 2017-03-01     16.609146
# 2017-03-02     16.620602
# 2017-03-03     16.649222
#                  ...
# 2022-02-18    300.008446
# 2022-02-22    293.418912
# 2022-02-23    288.436238
# 2022-02-24    271.944366
# 2022-02-25    271.284061
# Name: EMA_0.3, Length: 1260, dtype: float64

# %%
df_tesla[['Open','EMA_0.1','EMA_0.3']]
# Out:
#                   Open     EMA_0.1     EMA_0.3
# Date
# 2017-02-27   16.544666   16.544666   16.544666
# 2017-02-28   16.279333   16.518133   16.465066
# 2017-03-01   16.945333   16.560853   16.609146
# 2017-03-02   16.647333   16.569501   16.620602
# 2017-03-03   16.716000   16.584151   16.649222
# ...                ...         ...         ...
# 2022-02-18  295.333344  306.989372  300.008446
# 2022-02-22  278.043335  304.094768  293.418912
# 2022-02-23  276.809998  301.366291  288.436238
# 2022-02-24  233.463333  294.575995  271.944366
# 2022-02-25  269.743347  292.092730  271.284061
#
# [1260 rows x 3 columns]

# %%
df_tesla[['Open','EMA_0.1','EMA_0.3']].plot(xlim=['2020-01-01' ,'2021-01-01'],figsize =(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #alpha is smoothning factor

# %%
##EMA tesla shares
# Let's smoothing factor - 0.1
df_tesla['EMA_5days'] = df_tesla['Open'].ewm(span =5).mean()
#aplha is hyper  parameter and it is called smoothing factor

# %% [markdown]
# #span is specify decay in terms of span

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.ewm.html

# %% [markdown]
# apla = 2/(span+1)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.ewma.html

# %% [markdown]
# https://www.google.com/search?client=firefox-b-d&q=pandas+exponential+weighted+moving+average+examples

# %% [markdown]
# https://www.statology.org/exponential-moving-average-pandas/

# %%
df_tesla['EMA_5days']
# Out:
# Date
# 2017-02-27     16.544666
# 2017-02-28     16.385466
# 2017-03-01     16.650667
# 2017-03-02     16.649282
# 2017-03-03     16.674894
#                  ...
# 2022-02-18    299.833015
# 2022-02-22    292.569788
# 2022-02-23    287.316525
# 2022-02-24    269.365461
# 2022-02-25    269.491423
# Name: EMA_5days, Length: 1260, dtype: float64

# %%
df_tesla[['Open','EMA_5days']].plot(figsize =(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla[['Open','EMA_0.1','EMA_5days']].plot(figsize =(15,5))
# Out:
# <Axes: xlabel='Date'>
